# %%
import pandas as pd

# %%
# load data
data = pd.read_csv("Data_withSentiments.csv")
data.columns = data.columns.str.strip()
cols = ["View","Like","Dislike","duration_ms"]
data[cols]= data[cols].replace(",","", regex=True).astype(float)
data.columns = ['Year' if x=='Concert year (2018, 2019 or 2020) (song released before 2018 -> 2018)' else x for x in data.columns]

# %%
data.head()
# Out:
#        VideoID  Year        Artist                               Song Name  \
# 0  U9BwWKXjVaI  2018         Drake                           Nice For What
# 1  S1gp0m4B5p8  2019         Drake  Going Bad feat. Drake (Official Video)
# 2  xWggTb45brM  2020         Drake                            Toosie Slide
# 3  pok8H_KF1FA  2020      Doja Cat                 Say So (Official Video)
# 4  AqAJLh9wuZ0  2020  Taylor Swift                The Man (Official Video)
#
#           View       Like   Dislike  danceability  energy  speechiness  ...  \
# 0  348637112.0  2353239.0  130665.0         0.889   0.496        0.091  ...
# 1  109266381.0  1221814.0   40336.0         0.834   0.454        0.201  ...
# 2   59212131.0  1370881.0   49691.0         0.787   0.673        0.158  ...
# 3   85600520.0  2206882.0   36219.0         0.777   0.658        0.054  ...
# 4   37774922.0  1297372.0  142309.0         0.777   0.658        0.054  ...
#
#    liveness  valence  tempo            type  duration_ms popularity  \
# 0     0.252    0.544   86.0  audio_features     180522.0         84
# 1     0.114    0.837   82.0  audio_features     247059.0         99
# 2     0.090    0.786  111.0  audio_features     237893.0         97
# 3     0.090    0.633  110.0  audio_features     190360.0         83
# 4     0.090    0.633  110.0  audio_features     190360.0         83
#
#    neg_score  neu_score  pos_score  cou_score
# 0   0.087915   0.718298   0.193809   0.153996
# 1   0.100160   0.783780   0.116060   0.005444
# 2   0.058761   0.769391   0.171870   0.140309
# 3   0.032440   0.659060   0.308480   0.257262
# 4   0.095333   0.653111   0.229333   0.103829
#
# [5 rows x 22 columns]

# %%
X = data.loc[:,'Year':'cou_score']

# %%
X.shape
# Out:
# (162, 21)

# %%
##2018 sales data
data = pd.read_csv('2018YearEndTop100WorldwideTours_697.csv',header=1)
data.head()
df=data[['Millions','Artist']]
df['Millions']=pd.to_numeric(df['Millions'],errors='coerce')
# Out:
# C:\Users\anhng\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#Add year column
s=pd.Series([2018])
a=s.repeat(len(df))
a= a.reset_index(drop=True)
df['Year']=a
df.head()
# Out:
# C:\Users\anhng\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#    Millions           Artist  Year
# 0     432.4       Ed Sheeran  2018
# 1     345.1     Taylor Swift  2018
# 2     254.1  Jay-Z / Beyoncé  2018
# 3     169.2             Pink  2018
# 4     167.6       Bruno Mars  2018

# %%
#Change some variables to match the other data
df['Artist'][15]='Gun N Roses'
df['Artist'][3]='P!nk'
# Out:
# C:\Users\anhng\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\anhng\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\anhng\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(df)
# Out:
# 108

# %%
#Get valid data with target - DONT NEED TO RUN UNLESS dat_.csv doesn't work!!
#dat=pd.DataFrame(valid['Artist'].unique())
#dat.to_csv('dat.csv', index = False)

# %%
dat = pd.read_csv('dat_.csv',header=0)
dat.columns=['Artist','Millions']
dat['Millions']=pd.to_numeric(dat['Millions'],errors='coerce')
s=pd.Series([2019])
a=s.repeat(len(dat))
a= a.reset_index(drop=True)
dat['Year']=a
dat.head()
# Out:
#          Artist  Millions  Year
# 0         Drake      16.0  2019
# 1   Post Malone      95.8  2019
# 2  Shawn Mendes      86.6  2019
# 3      Maroon 5      32.1  2019
# 4    Bruno Mars      20.6  2019

# %%
#Split data set by year
train=X[X['Year']==2018]
valid=X[X['Year']==2019]
test=X[X['Year']==2020]

# %%
#Get train data with target 
train=pd.merge(train,df,on=['Artist','Year'],how='left')

# %%
#train.dtypes - check types of data
train[train['Millions'].isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Artist, Song Name, View, Like, Dislike, danceability, energy, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, popularity, neg_score, neu_score, pos_score, cou_score, Millions]
# Index: []
#
# [0 rows x 22 columns]

# %%
valid=pd.merge(valid,dat,on=['Artist','Year'],how='left')

# %%
valid[valid['Millions'].isna()]#-check to see if the merge is successful
# Out:
# Empty DataFrame
# Columns: [Year, Artist, Song Name, View, Like, Dislike, danceability, energy, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, popularity, neg_score, neu_score, pos_score, cou_score, Millions]
# Index: []
#
# [0 rows x 22 columns]

# %%
valid
# Out:
#     Year             Artist  \
# 0   2019              Drake
# 1   2019        Post Malone
# 2   2019       Shawn Mendes
# 3   2019           Maroon 5
# 4   2019         Bruno Mars
# 5   2019    Backstreet boys
# 6   2019             Eminem
# 7   2019             Eminem
# 8   2019             Eminem
# 9   2019               P!nk
# 10  2019               BTS
# 11  2019     Jennifer Lopez
# 12  2019        Post Malone
# 13  2019         Bruno Mars
# 14  2019         Ed Sheeran
# 15  2019               BTS
# 16  2019               BTS
# 17  2019         Ed Sheeran
# 18  2019      Ariana Grande
# 19  2019      Ariana Grande
# 20  2019          Lady Gaga
# 21  2019          Lady Gaga
# 22  2019      Ariana Grande
# 23  2019        Post Malone
# 24  2019             Khalid
# 25  2019             Khalid
# 26  2019             Khalid
# 27  2019             Khalid
# 28  2019       Marc Anthony
# 29  2019       Marc Anthony
# 30  2019  Twenty one pilots
# 31  2019  Twenty one pilots
# 32  2019        Chris Brown
# 33  2019        Chris Brown
#
#                                             Song Name          View  \
# 0              Going Bad feat. Drake (Official Video)  1.092664e+08
# 1                 "Goodbyes" ft. Young Thug (Rated R)  1.352628e+08
# 2                                           SeÃ±orita  9.983976e+08
# 3                                      girls like you  2.650000e+09
# 4                                           Please me  3.170000e+08
# 5                                             Chances  3.083052e+07
# 6                                            Homicide  5.527933e+07
# 7                                               Venom  3.900000e+08
# 8                                                Fall  1.690000e+08
# 9                       Walk Me Home (Official Video)  9.740898e+07
# 10                                          Boy w luv  7.605006e+08
# 11   "Medicine" ft. French Montana (Official Music...  2.967677e+07
# 12      Sunflower (Spider-Man: Into the Spider-Verse)  1.031223e+09
# 13          Wake Up in The Sky [Official Music Video]  3.338240e+08
# 14                      I Don't Care [Official Video]  3.812923e+08
# 15                                               IDOL  6.507139e+08
# 3   ...    0.476  125.000  audio_features     235545.0          0   0.020891
# 4   ...    0.650  134.000  audio_features     200890.0         77   0.030729
# 5   ...    0.296  110.000  audio_features     172627.0         57   0.029356
# 6   ...    0.770  140.000  audio_features     245387.0         77   0.149143
# 7   ...    0.460  136.000  audio_features     269554.0         75   0.076540
# 8   ...    0.535  183.000  audio_features     262494.0         72   0.158347
# 9   ...    0.432   88.000  audio_features     177391.0         73   0.051694
# 10  ...    0.798  120.000  audio_features     229773.0         84   0.053795
# 11  ...    0.457  102.000  audio_features     174159.0         58   0.057204
# 12  ...    0.913   90.000  audio_features     158040.0         87   0.052265
# 13  ...    0.367  143.000  audio_features     204665.0         78   0.092979
# 14  ...    0.812  102.000  audio_features     218373.0         53   0.106962
# 15  ...    0.422  126.000  audio_features     222732.0         75   0.055839
# 16  ...    0.490  147.000  audio_features     198261.0         80   0.056188
# 17  ...    0.548   93.000  audio_features     197867.0         86   0.053482
# 18  ...    0.327  140.048  audio_features     178627.0         88   0.035187
# 19  ...    0.335  170.000  audio_features     190440.0         82   0.059943
# 20  ...    0.296  130.000  audio_features     210200.0         80   0.063898
# 21  ...    0.323   96.000  audio_features     215733.0         87   0.040875
# 22  ...    0.702  190.000  audio_features     186107.0         83   0.093239
# 23  ...    0.341  145.000  audio_features     231267.0         86   0.102020
# 24  ...    0.346  136.000  audio_features     197573.0         80   0.060250
# 25  ...    0.112   98.000  audio_features     229320.0         79   0.062167
# 26  ...    0.110  140.000  audio_features     182080.0         76   0.062041
# 27  ...    0.391   85.000  audio_features     166101.0         68   0.122592
# 28  ...    0.967   96.000  audio_features     268440.0         70   0.005820
# 29  ...    0.652   97.000  audio_features     241760.0         64   0.024167
# 30  ...    0.315   90.000  audio_features     324467.0         79   0.075459
# 31  ...    0.371   87.000  audio_features     265373.0         70   0.050333
# 32  ...    0.483   82.000  audio_features     232733.0         75   0.032417
# 33  ...    0.137   93.000  audio_features     260640.0         82   0.095440
#
#     neu_score  pos_score  cou_score  Millions
# 0    0.783780   0.116060   0.005444      16.0
# 1    0.702979   0.169104   0.003908      95.8
# 2    0.709089   0.216778   0.144349      86.6
# 3    0.757500   0.199870   0.173046      32.1
# 4    0.771542   0.197729   0.129933      20.6
# 5    0.667000   0.259200   0.283571     100.2
# 6    0.742082   0.108816  -0.058773      38.0
# 7    0.745120   0.178340   0.083332      38.0
# 8    0.620531   0.200694   0.041073      38.0
# 9    0.713286   0.235020   0.224943     215.2
# 10   0.823727   0.099773   0.071243     170.3
# 11   0.740327   0.202510   0.179327      54.7
# 12   0.762878   0.164469   0.083120      95.8
# 13   0.801277   0.105745   0.010985      20.6
# 14   0.713415   0.160755   0.043534     211.7
# 15   0.714411   0.194036   0.121189     170.3
# 16   0.703313   0.178021   0.114710     170.3
# 17   0.477308   0.207215   0.173661     211.7
# 18   0.634938   0.309042   0.221708     118.3
# 19   0.721529   0.218529   0.162309     118.3
# 20   0.623878   0.312224   0.298984      48.4
# 21   0.628229   0.330896   0.301752      48.4
# 22   0.718696   0.188065   0.059754     118.3
# 23   0.635000   0.242980   0.154380      95.8
# 24   0.689000   0.229917   0.181615      33.9
# 25   0.658229   0.258771   0.157779      33.9
# 26   0.683612   0.233939   0.189647      33.9
# 27   0.630306   0.226735   0.066067      33.9
# 28   0.932960   0.041200   0.047878      27.3
# 29   0.895417   0.080396   0.094021      27.3
# 30   0.731514   0.175009   0.109367      43.9
# 31   0.670784   0.220059   0.149459      43.9
# 32   0.740604   0.226979   0.256629      18.6
# 33   0.703140   0.201400   0.143346      18.6
#
# [34 rows x 22 columns]

# %%
#Append train and valid data sets
train_valid = train.append(valid)
train_valid.tail()
# Out:
#     Year             Artist     Song Name         View       Like   Dislike  \
# 29  2019       Marc Anthony  Lo Que Te Di   37691486.0   178246.0    8861.0
# 30  2019  Twenty one pilots      Chlorine  220852337.0  2650297.0   48593.0
# 31  2019  Twenty one pilots      The Hype   28740475.0   784073.0    8176.0
# 32  2019        Chris Brown          Heat  102828883.0   825831.0   40426.0
# 33  2019        Chris Brown   No Guidance  181367542.0  2256408.0  111093.0
#
#     danceability  energy  speechiness  acousticness  ...  valence  tempo  \
# 29         0.714   0.891        0.034         0.608  ...    0.652   97.0
# 30         0.609   0.674        0.055         0.074  ...    0.315   90.0
# 31         0.530   0.816        0.050         0.011  ...    0.371   87.0
# 32         0.620   0.613        0.080         0.061  ...    0.483   82.0
# 33         0.698   0.454        0.151         0.123  ...    0.137   93.0
#
#               type  duration_ms popularity  neg_score  neu_score  pos_score  \
# 29  audio_features     241760.0         64   0.024167   0.895417   0.080396
# 30  audio_features     324467.0         79   0.075459   0.731514   0.175009
# 31  audio_features     265373.0         70   0.050333   0.670784   0.220059
# 32  audio_features     232733.0         75   0.032417   0.740604   0.226979
# 33  audio_features     260640.0         82   0.095440   0.703140   0.201400
#
#     cou_score  Millions
# 29   0.094021      27.3
# 30   0.109367      43.9
# 31   0.149459      43.9
# 32   0.256629      18.6
# 33   0.143346      18.6
#
# [5 rows x 22 columns]

# %%
#Data prep for sentimental analysis
train_x = train.loc[:,'View':'cou_score']
train_y=train.loc[:,'Millions']
valid_x = valid.loc[:,'View':'cou_score']
valid_y=valid.loc[:,'Millions']
test_x = test.loc[:,'View':'cou_score']
train_valid_x= train_valid.loc[:,'View':'cou_score']
train_valid_y=train_valid.loc[:,'Millions']

# %%
#train_y.head()-check data

# %%
train_x= pd.get_dummies(train_x,drop_first=True)
valid_x= pd.get_dummies(valid_x,drop_first=True)
test_x=pd.get_dummies(test_x,drop_first=True)
train_valid_x=pd.get_dummies(train_valid_x,drop_first=True)

# %%
#train_x-check data

# %%
train.to_csv('train.csv', index = False)
valid.to_csv('valid.csv', index = False)
test.to_csv('test.csv', index = False)
train_valid.to_csv('train_valid.csv', index = False)

train_x.to_csv('train_x.csv', index = False)
valid_x.to_csv('valid_x.csv', index = False)
test_x.to_csv('test_x.csv', index = False)
train_valid_x.to_csv('train_valid_x.csv', index = False)

train_y.to_csv('train_y.csv', index = False)
valid_y.to_csv('valid_y.csv', index = False)
train_valid_y.to_csv('train_valid_y.csv', index = False)
